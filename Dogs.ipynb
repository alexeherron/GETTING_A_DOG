# %%
# The purpose of this notebook is to gather the data from the Lawrence Humane Society's website for better compilation
# of my top-ten picks for our NEW DOG!!!!!!! OH MY GAAAAHHHH!!!!
# First step: import everything I'll need.

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# urls = ['https://lawrencehumane.org/details/?animal_id=A059273', 'https://lawrencehumane.org/details/?animal_id=A060976',
#         'https://lawrencehumane.org/details/?animal_id=A061584', 'https://lawrencehumane.org/details/?animal_id=A061264',
#         'https://lawrencehumane.org/details/?animal_id=A061263', 'https://lawrencehumane.org/details/?animal_id=A061426',
#         'https://lawrencehumane.org/details/?animal_id=A048525', 'https://lawrencehumane.org/details/?animal_id=A060254',
#         'https://lawrencehumane.org/details/?animal_id=A060433', 'https://lawrencehumane.org/details/?animal_id=A058991'
# ]
# I initially thought I'd need to loop through the ten pages and scrape each one, but when I tried scraping one of them, 
# it returned the data for every pet at the shelter.
# New plan: turn all of this data into a pandas dataframe and filter it to return just the ten I want to look at.

url = 'https://lawrencehumane.org/details/?animal_id=A059273'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">//<![CDATA[
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# //]]>
# </script>
# <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
# <!-- This site is optimized with the Yoast SEO plugin v19.7.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Details - Lawrence Humane</title>
# <link href="https://lawrencehumane.org/details/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Details - Lawrence Humane" property="og:title"/>
# <meta content="https://lawrencehumane.org/details/" property="og:url"/>
# <meta content="Lawrence Humane" property="og:site_name"/>
# <meta content="https://www.facebook.com/lawrencehumane" property="article:publisher"/>
# <meta content="2020-03-12T09:31:45+00:00" property="article:modified_time"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://lawrencehumane.org/details/","url":"https://lawrencehumane.org/details/","name":"Details - Lawrence Humane","isPartOf":{"@id":"https://lawrencehumane.org/#website"},"datePublished":"2020-03-12T09:31:39+00:00","dateModified":"2020-03-12T09:31:45+00:00","breadcrumb":{"@id":"https://lawrencehumane.org/details/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://lawrencehumane.org/details/"]}]},{"@type":"BreadcrumbList","@id":"https://lawrencehumane.org/details/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://lawrencehumane.org/"},{"@type":"ListItem","position":2,"name":"Details"}]},{"@type":"WebSite","@id":"https://lawrencehumane.org/#website","url":"https://lawrencehumane.org/","name":"Lawrence Humane","description":"","publisher":{"@id":"https://lawrencehumane.org/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://lawrencehumane.org/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"Organization","@id":"https://lawrencehumane.org/#organization","name":"Lawrence Humane","url":"https://lawrencehumane.org/","sameAs":["https://www.instagram.com/lawrencehumane","https://www.facebook.com/lawrencehumane"],"logo":{"@type":"ImageObject","inLanguage":"en-US","@id":"https://lawrencehumane.org/#/schema/logo/image/","url":"https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Heart-Green-01.png","contentUrl":"https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Heart-Green-01.png","width":900,"height":750,"caption":"Lawrence Humane"},"image":{"@id":"https://lawrencehumane.org/#/schema/logo/image/"}}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://lawrencehumane.org/feed/" rel="alternate" title="Lawrence Humane » Feed" type="application/rss+xml"/>
# <link href="https://lawrencehumane.org/comments/feed/" rel="alternate" title="Lawrence Humane » Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/lawrencehumane.org\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.0.7"}};
# /*! This file is auto-generated */
# !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode,e=(p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0),i.toDataURL());return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([129777,127995,8205,129778,127999],[129777,127995,8203,129778,127999])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);
# </script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 0.07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://lawrencehumane.org/wp-includes/css/dist/block-library/style.min.css?ver=6.0.7" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="global-styles-inline-css" type="text/css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-background-color{background-color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-background-color{background-color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-background-color{background-color: var(- ...
# </style>
# <link href="https://lawrencehumane.org/wp-content/plugins/hide-featured-image-on-all-single-pagepost//tnado-styles.css?ver=6.0.7" id="tnado_hidefi_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/themes/hello-elementor/style.min.css?ver=2.3.1" id="hello-elementor-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/themes/hello-elementor/theme.min.css?ver=2.3.1" id="hello-elementor-theme-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/lib/eicons/css/elementor-icons.min.css?ver=5.11.0" id="elementor-icons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/lib/animations/animations.min.css?ver=3.2.1" id="elementor-animations-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/css/frontend-legacy.min.css?ver=3.2.1" id="elementor-frontend-legacy-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/css/frontend.min.css?ver=3.2.1" id="elementor-frontend-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/elementor/css/post-12.css?ver=1689105513" id="elementor-post-12-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor-pro/assets/css/frontend.min.css?ver=3.2.1" id="elementor-pro-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/elementor/css/global.css?ver=1673973333" id="elementor-global-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/elementor/css/post-81.css?ver=1707201203" id="elementor-post-81-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/elementor/css/post-84.css?ver=1704753657" id="elementor-post-84-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/elementor/css/post-253.css?ver=1675972490" id="elementor-post-253-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Poppins%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto+Slab%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CSource+Sans+Pro%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic&amp;display=auto&amp;ver=6.0.7" id="google-fonts-1-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/lib/font-awesome/css/fontawesome.min.css?ver=5.15.1" id="elementor-icons-shared-0-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://lawrencehumane.org/wp-content/plugins/elementor/assets/lib/font-awesome/css/brands.min.css?ver=5.15.1" id="elementor-icons-fa-brands-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://lawrencehumane.org/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://lawrencehumane.org/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <script id="gtm4wp-form-move-tracker-js" src="https://lawrencehumane.org/wp-content/plugins/duracelltomi-google-tag-manager/js/gtm4wp-form-move-tracker.js?ver=1.12.3" type="text/javascript"></script>
# <link href="https://lawrencehumane.org/wp-json/" rel="https://api.w.org/"/><link href="https://lawrencehumane.org/wp-json/wp/v2/pages/724" rel="alternate" type="application/json"/><link href="https://lawrencehumane.org/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://lawrencehumane.org/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 6.0.7" name="generator"/>
# <link href="https://lawrencehumane.org/?p=724" rel="shortlink"/>
# <link href="https://lawrencehumane.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Flawrencehumane.org%2Fdetails%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://lawrencehumane.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Flawrencehumane.org%2Fdetails%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style type="text/css"> .ae_data .elementor-editor-element-setting {
#                         display:none !important;
#                 }
#                 </style>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">//<![CDATA[
# 	var dataLayer_content = {"pagePostType":"page","pagePostType2":"single-page","pagePostAuthor":"admin"};
# 	dataLayer.push( dataLayer_content );//]]>
# </script>
# <script data-cfasync="false">//<![CDATA[
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.'+'js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NMBN7S5');//]]>
# </script>
# <!-- End Google Tag Manager -->
# <!-- End Google Tag Manager for WordPress by gtm4wp.com --><script type="text/javascript">
#            var ajaxurl = "https://lawrencehumane.org/wp-admin/admin-ajax.php";
#          </script><link href="https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Branded-Hearts-02-150x150.png" rel="icon" sizes="32x32"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Branded-Hearts-02.png" rel="icon" sizes="192x192"/>
# <link href="https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Branded-Hearts-02.png" rel="apple-touch-icon"/>
# <meta content="https://lawrencehumane.org/wp-content/uploads/2020/02/LHS-Branded-Hearts-02.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			a, a:active, a:visited {
# color: #00aeef;
# }
# a:hover {
# color: #00457c;
# }
# @font-face {
#     font-family: 'Liquid Embrace';
#     src: url('https://lhs.bluesym7.work/wp-content/themes/hello-elementor/assets/fonts/LiquidEmbrace.eot');
#     src: url('https://lhs.bluesym7.work/wp-content/themes/hello-elementor/assets/fonts/LiquidEmbrace.eot?#iefix') format('embedded-opentype'),
#         url('https://lhs.bluesym7.work/wp-content/themes/hello-elementor/assets/fonts/LiquidEmbrace.woff2') format('woff2'),
#         url('https://lhs.bluesym7.work/wp-content/themes/hello-elementor/assets/fonts/LiquidEmbrace.woff') format('woff');
#     font-weight: normal;
#     font-style: normal;
# }
#
# /* this is for feed start */
# .feed_container {
#     max-width: 1440px;
# /*     width: 80%; */
#     margin: 0 auto;
# }
# .page-template-RSSFEEDSingle  .feed_container{
# 	 width: 80%;
# 	 padding-top: 180px;
# }
# .feed_wrapper .eachtab{
#     display: none;
#     flex-wrap: wrap;
#     justify-content: space-between;
# }
# .feed_wrapper .eachtab.active{
#     display: flex;
# }
# .feed_wrapper .feed_each {
# 	flex-basis: 24%;
#   position: relative;
#   margin-bottom: 15px;
# }
# .feed_each .animalname {
# position: absolute;
# bottom: 30px;
# width: 100%;
#
# }
# .feed_each .animalname h3 {
#  display: inline-block;
#  padding: 8px 20px;
#  background-color: #70a451;
#  margin: 0;
#  color: #FFF;
#  font-size: 25px;
#  font-family: 'Liquid Embrace';
# }
# .feed_each img {
#     height: 270px;
#     width: 100%;
#     object-fit: cover;
# }
# .feed_each  a.animaldetails {
#     position: absolute;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
# }
# .feed_details .animalname h3 {
#     font-size: 55px;
#     padding: 10px 35px;
#     font-family: 'Liquid Embrace';
#     color: #00457c;
# }
# .feed_details h4 {
# font-weight: 400;
#     font-size: 22px;
#     padding-bottom: 10px;
# }
# .feed_details h5 {
#     font-size: 18px;
#     font-weight: 400;
# }
# .feed_details p {
#     font-size: 16px;
# }
# .feed_details h6 {
#     font-weight: 600;
#     font-size: 20px;
#     margin: 8px 0;
# 	display:inline;
# }
# .feed_details img {
#     padding-top: 25px;
# 	display:block;
# 	margin:0 auto;
# }
# .feed_pagination .pagination {
#     position: relative;
#     padding: 6px 12px;
#     line-height: 1.4;
#     background-color: #fff;
#     border: 1px solid #00457c;
#     margin-left: -1px;
#     cursor: pointer;
# 	 user-select: none;
# 	font-weight:500;
# }
# .feed_container .feed_pagination {
#     text-align: center;
#     margin: 35px 0 35px 0;
#     padding: 10px;
# }
# .feed_pagination .pagination.active{
# color: #fff !important;
# background-color: #00457c !important;
# border-color: #00457c;
# }
# .feed_container .feed_filter {
# display: flex;
# flex-wrap: wrap;
# justify-content: space-between;
# background: #98cb55;
# padding: 10px;
# }
# .feed_container .feed_filter .each_option input{
# 	height:34px;
# 	border:none;
# }
# .feed_filter label {
# font-weight: 700;
# font-size: 18px;
# padding-right:5px;
# font-family: "Source Sans Pro", Sans-serif;
# }
# button.feed_search {
# height: 35px;
# font-size: 20px;
# line-height: 0;
# background-color: #00457c !important;
# border: #00457c;
# color: #fff;
# }
# .feed_filter select {
#   font-size: 16px;
#   padding: 5px 5px;
# 	border:none;
# }
# .feed_sort {
#     display: flex;
#     flex-wrap: wrap;
#     padding-right: 20px;
#     background: #00aeef;
# 	justify-content: space-between;
# }
# .feed_sort span {
#     cursor: pointer;
#     font-weight: 600;
#     font-size: 20px;
#     padding: 15px 20px;
#     font-family: "Source Sans Pro", Sans-serif;
# }
# .feed_sort span:first-child {
#     font-weight: 700;
#     color: #6b6477;
# }
# .feed_pagination .pagination:first-child {
#     border-radius: 6px 0 0 6px;
# }
# .feed_pagination .pagination:last-child {
#     border-radius: 0 6px 6px 0;
# }
#
# .feed_pagination a.pagination.active + span{
#  visibility:hidden;
# }
# .feed_pagination span:first-child{
#  visibility:hidden;
# }
# .feed_pagination.clicked span:first-child{
#  visibility:visible;
# 	border-radius:5px 0 0 5px;
# }
# .feed_pagination .pagination.active:nth-last-child(2) {
#     border-radius: 0 5px 5px 0;
# }
# .feed_pagination span {
#   cursor: pointer;
#   position: relative;
#   padding: 6px 12px;
#   text-decoration: none;
#   color: #00457c;
#   background-color: #fff;
#   border: 1px solid #00457c;
#   margin: 0 !important;
# 	user-select: none;
# 	text-transform: lowercase;
# }
#
# .each_option {
#     display: flex;
#     align-items: center;
# 	margin: 10px 0;
# }
#
# .feed_pagination .pagination:hover {
#     background: #eee;
# }
# .each_option.dev_disable .feed_search {
# background-color: #d4d4d4 !important;
# color: #727272;
# pointer-events: none;
# }
# .each_option.dev_disable {
#     cursor: no-drop;
# }
# .feed_pagination span + span {
#     display: none;
# }
# .feed_sort span.active {
#     background: #00457c;
#     color: #fff;
# }
# .feed_pagination span:last-child {
# right: 5px;
# border-radius: 0 5px 5px 0;
# }
# .feed_pagination span:first-child {
#     left: 5px;
# }
# .feed_pagination .pagination.active:nth-child(2) {
#     border-radius: 5px 0 0 5px;
# }
# .page-template-RSSFEEDSingle .feed_container .feed_details {
#     width: 65%;
#     margin: 0 auto;
# 	text-align:center;
# 	padding-bottom:50px
# }
# .feed_details h6.dev_notice {
#     padding: 20px 0;
#     display: block;
# }
# .feed_details .animalname:after {
#     content: '';
#     display: block;
#     width: 100px;
#     height: 20px;
#     margin: 0 auto;
#     background-image: url(https://lhs.bluesym7.work/wp-content/uploads/2020/03/dark-blue.png);
#     background-size: contain;
#     background-repeat: no-repeat;
# }
# .feed_details .animalname {
#     padding-bottom: 35px;
# }
# .pagination + span {
#     right: 5px;
#     border-radius: 0 5px 5px 0;
# }
# .feed_container > div:nth-child(3) {
#     display: none;
# }
# .feed_container .feed_wrapper {
#     padding-top: 50px;
# }
# @media(max-width:1024px){
# .page-template-RSSFEEDSingle .feed_container {
#     padding-top: 100px;
# }
# }
# @media(max-width:768px){
# 	.page-template-RSSFEEDSingle .feed_container .feed_details{
# 		width:100%;
# 	}
# 	.feed_pagination .pagination{
# 		    padding: 6px 7px !important;
# 	}
#
# 	.feed_container .feed_pagination span {
#     display: block;
#     width: 200px;
#     margin: 15px auto !important;
# 		border-radius:5px !important;
# }
# 	.feed_wrapper .feed_each {
#     flex-basis: 48%;
# 		margin-bottom: 20px;
# }
#
# .feed_details .animalname h3 {
#   font-size: 40px;
# }
# .feed_details h4 {
#     font-size: 25px;
# 		padding-bottom: 15px;
# }
# 	.feed_details h6 {
# 		font-size: 16px;
# 	}
# 	.feed_container .feed_pagination{
# 		margin:0 !important;
# 	}
# }
# @media(max-width:767px){
# 	.page-template-RSSFEEDSingle .feed_container {
#     padding-top: 250px;
# }
# }
# @media(max-width:600px){
# 	.feed_wrapper .feed_each {
#     flex-basis: 100%;
# 		margin-bottom: 20px;
# }
# }
# /* this is for feed end */		</style>
# </head>
# <body class="page-template page-template-RSSFEEDSingle page-template-RSSFEEDSingle-php page page-id-724 wp-custom-logo elementor-default elementor-kit-12">
# <svg focusable="false" height="0" role="none" style="visibility: hidden; position: absolute; left: -9999px; overflow: hidden;" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><defs><filter id="wp-duotone-dark-grayscale"><fecolormatrix color-interpolation-filters="sRGB" type="matrix" values=" .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 "></fecolormatrix><fecomponenttransfer color-interpolation-filters="sRGB"><fefuncr tablevalues="0 0.49803921568627" type="table"></fefuncr><fefuncg tablevalues="0 0.49803921568627" type="table"></fefuncg><fefuncb tablevalues="0 0.49803921568627" type="table"></fefuncb><fefunca tablevalues="1 1" type="table"></fefunca></fecomponenttransfer><fecomposite in2="SourceGraphic" operator="in"></fecomposite></filter></defs></svg><svg focusable="false" height="0" role="none" style="visibility: hidden; position: absolute; left: -9999px; overflow: hidden;" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><defs><filter id="wp-duotone-grayscale"><fecolormatrix color-interpolation-filters="sRGB" type="matrix" values=" .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 "></fecolormatrix><fecomponenttransfer color-interpolation-filters="sRGB"><fefuncr tablevalues="0 1" type="table"></fefuncr><fefuncg tablevalues="0 1" type="table"></fefuncg><fefuncb tablevalues="0 1" type="table"></fefuncb><fefunca tablevalues="1 1" type="table"></fefunca></fecomponenttransfer><fecomposite in2="SourceGraphic" operator="in"></fecomposite></filter></defs></svg><svg focusable="false" height="0" role="none" style="visibility: hidden; position: absolute; left: -9999px; overflow: hidden;" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><defs><filter id="wp-duotone-purple-yellow"><fecolormatrix color-interpolation-filters="sRGB" type="matrix" values=" .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 "></fecolormatrix><fecomponenttransfer color-interpolation-filters="sRGB"><fefuncr tablevalues="0.54901960784314 0.98823529411765" type="table"></fefuncr><fefuncg tablevalues="0 1" type="table"></fefuncg><fefuncb tablevalues="0.71764705882353 0.25490196078431" type="table"></fefuncb><fefunca tablevalues="1 1" type="table"></fefunca></fecomponenttransfer><fecomposite in2="SourceGraphic" operator="in"></fecomposite></filter></defs></svg><svg focusable="false" height="0" role="none" style="visibility: hidden; position: absolute; left: -9999px; overflow: hidden;" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><defs><filter id="wp-duotone-blue-red"><fecolormatrix color-interpolation-filters="sRGB" type="matrix" values=" .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 "></fecolormatrix><fecomponenttransfer color-interpolation-filters="sRGB"><fefuncr tablevalues="0 1" type="table"></fefuncr><fefuncg tablevalues="0 0.27843137254902" type="table"></fefuncg><fefuncb tablevalues="0.5921568627451 0.27843137254902" type="table"></fefuncb><fefunca tablevalues="1 1" type="table"></fefunca></fecomponenttransfer><fecomposite in2="SourceGraphic" operator="in"></fecomposite></filter></defs></svg><svg focusable="false" height="0" role="none" style="visibility: hidden; position: absolute; left: -9999px; overflow: hidden;" viewbox="0 0 0 0" width="0" xmlns="http://www.w3.org/2000/svg"><defs><filter id="wp-duotone-midnight"><fecolormatrix color-interpolation-filters="sRGB" type="matrix" values=" .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 .299 .587 .114 0 0 "></fecolormatrix><fecomponenttransfer color-interpolation-filters="sRGB"><fefuncr tablevalues="0 0" type="table"></fefuncr><fefuncg tablevalues="0 0.64705882352941" type="table"></fefuncg><fefuncb tablevalues="0 1" type="table"></fefuncb><fefunca tablevalues="1 1" type="table"></fefunca></fecomponenttransfer><fecomposite in2="SourceGraphic" operator="in"></fecomposite></filter></defs></svg><svg focusable="false" height="0" role= ...
# <div class="elementor-section-wrap">
# <section class="elementor-section elementor-top-section elementor-element elementor-element-4aacaea4 elementor-section-full_width elementor-hidden-tablet elementor-hidden-phone elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="4aacaea4" data-settings='{"background_background":"classic"}'>
# <div class="elementor-background-overlay"></div>
# <div class="elementor-container elementor-column-gap-default">
# <div class="elementor-row">
# <div class="elementor-column elementor-col-100 elementor-top-column elementor-element elementor-element-5fb15bf0" data-element_type="column" data-id="5fb15bf0" data-settings='{"background_background":"classic"}'>
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <section class="elementor-section elementor-inner-section elementor-element elementor-element-7b560e31 elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="7b560e31">
# <div class="elementor-container elementor-column-gap-default">
# <div class="elementor-row">
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-72c35eb" data-element_type="column" data-id="72c35eb">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-7c59759 elementor-widget elementor-widget-image" data-element_type="widget" data-id="7c59759" data-widget_type="image.default">
# <div class="elementor-widget-container">
# <div class="elementor-image">
# <a href="https://lawrencehumane.org/home/">
# <img alt="" class="attachment-medium_large size-medium_large" height="221" loading="lazy" sizes="(max-width: 768px) 100vw, 768px" src="https://lawrencehumane.org/wp-content/uploads/2020/02/Lawrence-Humane-Valentines-768x221.png" srcset="https://lawrencehumane.org/wp-content/uploads/2020/02/Lawrence-Humane-Valentines-768x221.png 768w, https://lawrencehumane.org/wp-content/uploads/2020/02/Lawrence-Humane-Valentines-300x86.png 300w, https://lawrencehumane.org/wp-content/uploads/2020/02/Lawrence-Humane-Valentines-1024x295.png 1024w, https://lawrencehumane.org/wp-content/uploads/2020/02/Lawrence-Humane-Valentines.png 1368w" width="768"/> </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-4e3021eb" data-element_type="column" data-id="4e3021eb">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-596602c elementor-nav-menu__align-center elementor-nav-menu--dropdown-mobile elementor-nav-menu--stretch elementor-nav-menu--indicator-classic elementor-nav-menu__text-align-aside elementor-nav-menu--toggle elementor-nav-menu--burger elementor-widget elementor-widget-nav-menu" data-element_type="widget" data-id="596602c" data-settings='{"full_width":"stretch","layout":"horizontal","toggle":"burger"}' data-widget_type="nav-menu.default">
# <div class="elementor-widget-container">
# <nav class="elementor-nav-menu--main elementor-nav-menu__container elementor-nav-menu--layout-horizontal e--pointer-underline e--animation-grow" role="navigation"><ul class="elementor-nav-menu" id="menu-1-596602c"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8978"><a class="elementor-item" href="https://lawrencehumane.org/adopt/">Adopt</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9017"><a class="elementor-sub-item" href="https://lawrencehumane.org/adopt">Pets for Adoption</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9020"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/adopt/#faqs">Adoption FAQs</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9018"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/adopt/#specials">Adoption Specials</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9019"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/adopt/#request">Request a Pet</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9021"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/adopt/#espurresso">Espurresso Cat Cafe</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8979"><a class="elementor-item" href="https://lawrencehumane.org/getinvolved/">Get Involved</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-10807"><a class="elementor-sub-item" href="https://lawrencehumane.org/foster">Foster</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9015"><a class="elementor-sub-item" href="https://lawrencehumane.org/foster/">Become a Foster</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9014"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/foster/#faqs">Foster FAQS</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8984"><a class="elementor-sub-item" href="https://lawrencehumane.org/volunteer/">Volunteer</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9012"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/volunteer/#FAQS">About the Program</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9011"><a class="elementor-sub-item" href="https://lawrencehumane.org/volunteer/">Become a Volunteer</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-8998"><a class="elementor-sub-item" href="https://app.betterimpact.com/Login/LoginNoSearch?agencyGuid=e79f8667-282c-47d1-bcc7-2412bf422cd2">Volunteer Login</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9013"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/volunteer/#groupservice">Group Service Projects</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8982"><a class="elementor-sub-item" href="https://lawrencehumane.org/events/">Events</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9016"><a class="elementor-sub-item" href="https://lawrencehumane.org/events">Upcoming Events</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9022"><a class="elementor-sub-item" href="https://lawrencehumane.org/2023sponsorships/">Sponsorship Opportunities</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9026"><a class="elementor-sub-item" href="https://lawrencehumane.org/connect">Connect</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9028"><a class="elementor-sub-item" href="https://form.jotform.com/220454977132154">Sign up for our Newsletter</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9029"><a class="elementor-sub-item" href="https://form.jotform.com/221525009061141">Share Your Story</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9030"><a class="elementor-sub-item" href="https://lawrencehumane.org/connect">Socials</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10905"><a class="elementor-sub-item" href="https://lawrencehumane.org/wet-nose-news/">Wet Nose News</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8980"><a class="elementor-item" href="https://lawrencehumane.org/donate/">Donate</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9045"><a class="elementor-sub-item" href="https://lawrencehumane.org/donate">Donations</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9048"><a class="elementor-sub-item elementor-item-anchor" href="https://www.classy.org/give/409518/#!/donation/checkout">Donate Now</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9049"><a class="elementor-sub-item" href="https://www.classy.org/campaign/become-a-monthly-donor/c457857">Monthly Giving</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9134"><a class="elementor-sub-item" href="https://lawrencehumane.org/giftofgiving/">Give the Gift of Giving</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9050"><a class="elementor-sub-item" href="https://lawrencehumane.org/crisispetretention">Crisis Pet Retention Fund</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9051"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#honor">Honor &amp; Memorial Gifts</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9052"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#workplace">Workplace Giving</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9047"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#other">Other Ways To Give</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9122"><a class="elementor-sub-item" href="https://www.amazon.com/hz/wishlist/ls/3HLXEIKMN0WK0?ref_=wl_share">Amazon Wishlist</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9123"><a class="elementor-sub-item" href="https://www.chewy.com/g/lawrence-humane-society-inc_b74514656">Chewy Wishlist</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9126"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#mostneeded">Most Needed Donations</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9125"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#mostneeded">In-Kind Donations</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9128"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#other">First State Debit Card</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9031"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#donationdrive">Host a Donation Drive</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9127"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#other">Vehicle Donations</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9129"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/donate/#other">Dillons Community Rewards</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9124"><a class="elementor-sub-item" href="https://www.walmart.com/sparkgood">Walmart Spark for Good</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9046"><a class="elementor-sub-item" href="https://lawrencehumane.org/2023sponsorships/">Sponsorship Opportunities</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9034"><a class="elementor-item" href="https://lawrencehumane.org/services">Services</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9061"><a class="elementor-sub-item" href="https://lawrencehumane.org/services">Pet Resource Center</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10916"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/services/#lost">I Lost a Pet</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9069"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/services/#found">I Found a Pet</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9067"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/services/#reclaim">Reclaim a Pet</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9068"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/services/#surrender">Surrender a Pet</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-9062"><a class="elementor-sub-item" href="https://lawrencehumane.org/crisispetretention/">Crisis Pet Retention</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9071"><a class="elementor-sub-item" href="http://lawrencehumane.org/crisispetretention">Crisis Pet Retention FAQS</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9072"><a class="elementor-sub-item" href="http://lawrencehumane.org/crisispetretention">Apply for assistance</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9073"><a class="elementor-sub-item" href="http://lawrencehumane.org/crisispetretention">Pet Pantry</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9074"><a class="elementor-sub-item" href="https://lawrencehumane.org/crisispetretention-spanish/">Español</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-9063"><a class="elementor-sub-item" href="https://lawrencehumane.org/lostandfound/">Lost and Found</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9075"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/petresourcecenter/#lost">Lost Pet Resources</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9131"><a class="elementor-sub-item" href="https://lawrencehumane.org/events">Facebook Page</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9133"><a class="elementor-sub-item" href="https://lost.petcolove.org/">Petco Love Lost</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9132"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/lostandfound/#tips">Flyer Template</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-9064"><a class="elementor-sub-item" href="https://lawrencehumane.org/animalservices/">Animal Services</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9076"><a class="elementor-sub-item" href="https://lawrencehumane.org/animalservices">Learn More</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9077"><a class="elementor-sub-item" href="https://form.jotform.com/221518493888167">Report a Complaint</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9065"><a class="elementor-sub-item" href="https://lawrencehumane.org/publicservices">Public Services</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9078"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/publicservices/#microchip">Microchipping</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10987"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/publicservices/#vaccine-clinics">Vaccine Clinics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9079"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/publicservices/#spay-neuter">Spay/Neuter</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9083"><a class="elementor-sub-item" href="https://lawrencehumane.org/publicservices">Trap Rentals</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9080"><a class="elementor-sub-item" href="https://lawrencehumane.org/publicservices">ID Tags</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9081"><a class="elementor-sub-item" href="https://lawrencehumane.org/publicservices">TNVR (Cats)</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9066"><a class="elementor-sub-item" href="https://lawrencehumane.org/resources">Pet Resources</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9084"><a class="elementor-sub-item" href="https://lawrencehumane.org/resources">GoodPup Training</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9085"><a class="elementor-sub-item" href="https://lawrencehumane.org/resources">Behavior Resources</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9086"><a class="elementor-sub-item" href="https://lawrencehumane.org/resources">Kitten Information</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9039"><a class="elementor-item" href="https://lawrencehumane.org/about">About</a>
# <ul class="sub-menu elementor-nav-menu--dropdown">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11959"><a class="elementor-sub-item" href="https://lawrencehumane.org/ourimpact/">Our Impact</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10925"><a class="elementor-sub-item" href="https://lawrencehumane.org/ourteam/">Our Team</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10924"><a class="elementor-sub-item" href="https://lawrencehumane.org/2021/04/03/70-years-of-lhs/">Our Story</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9042"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/ourteam/#boardofdirectors">Board Members</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9041"><a class="elementor-sub-item elementor-item-anchor" href="https://lawrencehumane.org/ourteam/#employee">Employment</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-9043"><a class="elementor-sub-item" href="https://lawrencehumane.org/shop/">Shop</a></li>
# ...
# 			jQuery("input.animal_id").val("");
# 			jQuery(".feed_search").parent(".each_option").removeClass("dev_disable");
#             }
#             var gender = jQuery("#gender option:selected" ).val();
#             if(gender == check){}
#             else{
#             jQuery(".feed_search").attr('data-gender', gender );
# 			jQuery(".feed_search").attr('data-id', "" );
# 			jQuery("input.animal_id").val("");
# 			jQuery(".feed_search").parent(".each_option").removeClass("dev_disable");
#             }
#             var size = jQuery("#size option:selected" ).val();
#             if(size == check){}
#             else{
#             jQuery(".feed_search").attr('data-size', size );
# 			jQuery(".feed_search").attr('data-id', "" );
# 			jQuery("input.animal_id").val("");
# 			jQuery(".feed_search").parent(".each_option").removeClass("dev_disable");
#             }
#             var color = jQuery("#color option:selected" ).val();
#             if(color == check){}
#             else{
#             jQuery(".feed_search").attr('data-color', color );
# 			jQuery(".feed_search").attr('data-id', "" );
# 			jQuery("input.animal_id").val("");
# 			jQuery(".feed_search").parent(".each_option").removeClass("dev_disable");
#             }
#         });
#         jQuery(".feed_filter input").change(function(){
#             var id = jQuery("input.animal_id" ).val();
#             jQuery(".feed_search").attr('data-id', id );
# 			jQuery(".feed_search").attr('data-type', "" );
# 			jQuery(".feed_search").attr('data-gender', "" );
# 			jQuery(".feed_search").attr('data-size', "" );
# 			jQuery(".feed_search").attr('data-color', "" );
# 			jQuery("#type option[value=Any]").prop('selected', 'selected');
# 			jQuery("#gender option[value=Any]").prop('selected', 'selected');
# 			jQuery("#size option[value=Any]").prop('selected', 'selected');
# 			jQuery("#color option[value=Any]").prop('selected', 'selected');
# 			jQuery(".feed_search").parent(".each_option").removeClass("dev_disable");
#         });
#     });
#
#     jQuery(document).ready(function(){
#             jQuery('.feed_search').click(function(){
#             var feed_type = jQuery(this).attr("data-type");
#             var feed_gender = jQuery(this).attr("data-gender");
#             var feed_size = jQuery(this).attr("data-size");
#             var feed_color = jQuery(this).attr("data-color");
#             var feed_id = jQuery(this).attr("data-id");
# 				// jQuery(this).attr("data-type", "");
#     //             jQuery(this).attr("data-gender", "");
#     //             jQuery(this).attr("data-size", "");
#     //             jQuery(this).attr("data-color", "");
#     //             jQuery(this).attr("data-id", "");
# 				// jQuery("#type option[value=Any]").prop('selected', 'selected');
# 				// jQuery("#gender option[value=Any]").prop('selected', 'selected');
# 				// jQuery("#size option[value=Any]").prop('selected', 'selected');
# 				// jQuery("#color option[value=Any]").prop('selected', 'selected');
# 				// jQuery("input.animal_id").val("");
# 				jQuery(".feed_search").parent(".each_option").addClass("dev_disable");
#             var data = {
#                 action: 'get_feed_filter',
#                 feed_type: feed_type,
#                 feed_gender: feed_gender,
#                 feed_size: feed_size,
#                 feed_color: feed_color,
#                 id: feed_id,
#             }
#             jQuery.post(ajaxurl, data, function(response){
#                 var datas = JSON.parse(response);
#                 var return_data = datas['data'];
#                 var htmlToAdd = '';
#                 var count = 0;
# //alert('before jquery each count: '+count+' data: '+data);
#                 jQuery.each(return_data, function(index, value){
#                     //console.log(value['animalName']);
# //alert('about to if count: '+count);
#                     if (count == 0) {
# //alert('in if count: '+count);
#                         htmlToAdd+= `<div class="eachtab active"><div class="feed_each" data-name="`+value['animalName']+`" data-gender="`+value['animalGender']+`" data-color="`+value['primaryColor']+`" data-breed="`+value['primaryBreed']+`" data-age="`+value['animalAge']+`" data-location="" data-intakedate="`+value['intakeDate']+`">
#                                 <img src="`+value['imageURL']+`">
#                                 <div class="animalname"><h3>`+value['animalName']+`</h3></div>
#                                 <a href="`+value['detailsurl']+`" class="animaldetails"></a>
#                                 </div>`
#                         count++;
#
#                     } else if (count % 8 == 0) {
#                         htmlToAdd+= `</div><div class="eachtab "><div class="feed_each" data-name="`+value['animalName']+`" data-gender="`+value['animalGender']+`" data-color="`+value['primaryColor']+`" data-breed="`+value['primaryBreed']+`" data-age="`+value['animalAge']+`" data-location="" data-intakedate="`+value['intakeDate']+`">
#                                 <img src="`+value['imageURL']+`">
#                                 <div class="animalname"><h3>`+value['animalName']+`</h3></div>
#                                 <a href="`+value['detailsurl']+`" class="animaldetails"></a>
#                                 </div>`
#                         count++;
#                     }
#                     else{
#                         htmlToAdd+= `<div class="feed_each" data-name="`+value['animalName']+`" data-gender="`+value['animalGender']+`" data-color="`+value['primaryColor']+`" data-breed="`+value['primaryBreed']+`" data-age="`+value['animalAge']+`" data-location="" data-intakedate="`+value['intakeDate']+`">
#                                 <img src="`+value['imageURL']+`">
#                                 <div class="animalname"><h3>`+value['animalName']+`</h3></div>
#                                 <a href="`+value['detailsurl']+`" class="animaldetails"></a>
#                                 </div>`
#                         count++;
#                     }
#
#                     jQuery('.feed_wrapper').html(htmlToAdd);
#                 })
#                 htmlToAdd = '';
#                 var num = 0;
#                 var i;
#                     for (i = count; i > 0; i= i-8) {
#                             num++;
#                     }
#                             num++;
#                             var tempnum = '.feed_pagination > a:nth-child(' + num + ')';
#                             jQuery(tempnum).nextAll().remove();
#                             jQuery(".feed_pagination").append("<span>Next Page</span>")
#             });
#             return false;
#         })
#     });
#
#
# // js code for sorting starting
#
# jQuery(document).ready(function() {
#
#
# //start of name click function
#     jQuery(".sort_name").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('name') < jQuery(b).data('name')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#        jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of name click function
#
#
#     //start of gender click function
#     jQuery(".sort_gender").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('gender') < jQuery(b).data('gender')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#        jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of gender click function
#
#         //start of color click function
#     jQuery(".sort_color").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('color') < jQuery(b).data('color')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#         jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of color click function
#
#   //start of breed click function
#     jQuery(".sort_bread").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('breed') < jQuery(b).data('breed')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#         jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of breed click function
#
#   //start of age click function
#     jQuery(".sort_age").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('age') < jQuery(b).data('age')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#         jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of age click function
#
#   //start of location click function
#     jQuery(".sort_location").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('location') < jQuery(b).data('location')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#         jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of location click function
#
#   //start of intake click function
#     jQuery(".sort_tshelter").click(function() {
# 		jQuery(".feed_sort span").removeClass("active");
# 		jQuery(this).addClass("active");
#         jQuery('.eachtab >div').sort(function(a, b) {
#             if (jQuery(a).data('intakedate') < jQuery(b).data('intakedate')) {
#                 return -1;
#             } else {
#                 return 1;
#             }
#         }).appendTo('.feed_wrapper');
#         wrapper();
#        jQuery('.eachtab').each(function() {
#             var $this =jQuery(this);
#             if ($this.html().replace(/\s|&nbsp;/g, '').length == 0)
#                 $this.remove();
#         });
#         jQuery(".feed_wrapper .eachtab:first-child").addClass("active");
#         jQuery(".feed_pagination .pagination").removeClass("active");
# 		jQuery(".feed_pagination").removeClass("clicked");
#         jQuery(".feed_pagination .pagination:nth-child(2)").addClass("active");
#     }); //end of intake click function
#
# function wrapper() {
#         (function($) {
#             $.fn.wrapChildren = function(options) {
#                 var options = $.extend({
#                     childElem: undefined,
#                     sets: 1,
#                     wrapper: 'div'
#                 }, options || {});
#                 if (options.childElem === undefined) return this;
#                 return this.each(function() {
#                     var elems =$(this).children(options.childElem);
#                     var arr = [];
#                     elems.each(function(i, value) {
#                         arr.push(value);
#                         if (((i + 1) % options.sets === 0) || (i === elems.length - 1)) {
#                             var set = $(arr);
#                             arr = [];
#                             set.wrapAll($("<" + options.wrapper + ">"));
#                         }
#                     });
#                 });
#             }
#         })(jQuery);
#
#             jQuery('.feed_wrapper ').wrapChildren({
#                 childElem: '.feed_each',
#                 sets: 8,
#                 wrapper: 'div class="eachtab"'
#             });
# }
# });
# // js code for sorting starting
#
# jQuery(document).ready(function(){
#     jQuery(".feed_pagination span:first-child").click(function(){
#         var divindex = jQuery(".feed_pagination a.active").index();
# 		console.log(divindex);
#         var divindex2 = divindex-1;
#         var tempindex = '.feed_container .feed_wrapper > div:nth-child(' + divindex2 + ')';
#         var tempindex2 = '.feed_pagination > a:nth-child(' + divindex + ')';
#         jQuery(".feed_container .feed_wrapper >div").removeClass("active")
#         jQuery(".feed_pagination > a").removeClass("active")
#         jQuery(tempindex).addClass("active");
#         jQuery(tempindex2).addClass("active");
# 		if(divindex == 2){
# 			jQuery(".feed_pagination").removeClass("clicked");
# 		}
#     });
#     jQuery(".feed_pagination span:last-child").click(function(){
#         var divnext = jQuery(".feed_pagination a.active").index();
#
#         var divnext2 = divnext + 2;
#         divnext = divnext + 1;
#         var tempnext = '.feed_container .feed_wrapper > div:nth-child(' + divnext + ')';
#         var tempnext2 = '.feed_pagination > a:nth-child(' + divnext2 + ')';
#         jQuery(".feed_container .feed_wrapper >div").removeClass("active")
#         jQuery(".feed_pagination > a").removeClass("active")
#         jQuery(tempnext).addClass("active");
#         jQuery(tempnext2).addClass("active");
# 		jQuery(".feed_pagination").addClass("clicked");
#     });
# 	jQuery(".feed_pagination a").click(function(){
# 		jQuery(".feed_pagination").addClass("clicked");
# 	});
# 	jQuery(".feed_pagination > a:nth-child(2)").click(function(){
# 		jQuery(".feed_pagination").removeClass("clicked");
# 	});
#
# });
# </script>
# </body>
# </html>

# %%
# It looks like the data for each pet is encased in a div with class='feed_details', so let's return those as a messy soup.
messy_soup = soup.find_all('div', class_ = 'feed_details')
messy_soup
# Out:
# [<div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Trixie.</h3></div>
#  <h4>#A057706</h4>
#  <p>I am currently in foster care so email adoptions@lawrencehumane.org to learn more about me!</p>
#  <h6>My name is Trixie</h6>
#  <h6>I am a Female, White, Shorthaired Rabbit. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 3 pounds.</h6>
#  <h6>My adoption price is $40.</h6>
#  <h6>I have been at the shelter since 08/09/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A057706"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A057706&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Bandit.</h3></div>
#  <h4>#A061533</h4>
#  <p></p>
#  <h6>My name is Bandit</h6>
#  <h6>I am a Male, White, Rat. </h6>
#  <h6>The shelter staff think I am about 1 year old.</h6>
#  <h6>I weigh approximately 1 pounds.</h6>
#  <h6>My adoption price is $5.</h6>
#  <h6>I have been at the shelter since 02/05/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061533"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061533&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M </h3></div>
#  <h4>#A061679</h4>
#  <p></p>
#  <h6>My name is </h6>
#  <h6>I am a Male, Gray, Domestic Longhair. </h6>
#  <h6>I'm estimated to be about 5 years old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>I was found as a stray on  02/12/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061679"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061679&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M </h3></div>
#  <h4>#A061731</h4>
#  <p></p>
#  <h6>My name is </h6>
#  <h6>I am a Unknown Gender, Black, Domestic Shorthair. </h6>
#  <h6>I'm estimated to be about Unknown.</h6>
#  <h6>I weigh approximately .</h6>
#  <h6>I was found as a stray on  02/14/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061731"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061731&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Turkey.</h3></div>
#  <h4>#A061632</h4>
#  <p></p>
#  <h6>My name is Turkey</h6>
#  <h6>I am a Female, Yellow, Parakeet. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately .</h6>
#  <h6>My adoption price is $5.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061632"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061632&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Poppy</h3></div>
#  <h4>#A059946</h4>
#  <p></p>
#  <h6>My name is Poppy</h6>
#  <h6>I am a Female, Black, Australian Cattle Dog. </h6>
#  <h6>I'm estimated to be about 3 years old.</h6>
#  <h6>I weigh approximately 44 pounds.</h6>
#  <h6>I was found as a stray on  02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059946"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059946&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Coco</h3></div>
#  <h4>#A043416</h4>
#  <p></p>
#  <h6>My name is Coco</h6>
#  <h6>I am a Female, Brown, Pit Bull Terrier. </h6>
#  <h6>I'm estimated to be about Unknown.</h6>
#  <h6>I weigh approximately 52 pounds.</h6>
#  <h6>I was found as a stray on  02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A043416"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A043416&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M </h3></div>
#  <h4>#A061700</h4>
#  <p></p>
#  <h6>My name is </h6>
#  <h6>I am a Male, Brown, Mixed Shepherd. </h6>
#  <h6>I'm estimated to be about 1 year old.</h6>
#  <h6>I weigh approximately .</h6>
#  <h6>I was found as a stray on  02/13/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061700"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061700&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M </h3></div>
#  <h4>#A061760</h4>
#  <p></p>
#  <h6>My name is </h6>
#  <h6>I am a Male, Gray, Pit Bull Terrier. </h6>
#  <h6>I'm estimated to be about 3 years old.</h6>
#  <h6>I weigh approximately 76 pounds.</h6>
#  <h6>I was found as a stray on  02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061760"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061760&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M </h3></div>
#  <h4>#A061781</h4>
#  <p></p>
#  <h6>My name is </h6>
#  <h6>I am a Male, Black, Labrador Retriever. </h6>
#  <h6>I'm estimated to be about Unknown.</h6>
#  <h6>I weigh approximately .</h6>
#  <h6>I was found as a stray on  02/16/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061781"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061781&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Maximus.</h3></div>
#  <h4>#A059273</h4>
#  <p></p>
#  <h6>My name is Maximus</h6>
#  <h6>I am a Male, Brown, Mixed Shepherd. </h6>
#  <h6>The shelter staff think I am about 11 months old.</h6>
#  <h6>I weigh approximately 38 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/14/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059273"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059273&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Zara.</h3></div>
#  <h4>#A061451</h4>
#  <p>Zara is a sweet girl who loves 'sunning her buns' in her kennel. (We had to give her a bit of a haircut when she came in so she doesn't have as much hair as usual!) She's shy but oh my goodness, a soft scritch or two and she is one sweet, gooey pile of love. Come to Lawrence Humane any day during adoption hours to meet her. Don't let the chance to adopt her melt through your fingers!</p>
#  <h6>My name is Zara</h6>
#  <h6>I am a Female, Brown Tiger, Domestic Longhair. </h6>
#  <h6>The shelter staff think I am about 1 year and 7 months old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/30/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061451"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061451&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Cain.</h3></div>
#  <h4>#A059403</h4>
#  <p></p>
#  <h6>My name is Cain</h6>
#  <h6>I am a Male, Tan, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 7 years old.</h6>
#  <h6>I weigh approximately 58 pounds.</h6>
#  <h6>My adoption price is $75.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059403"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059403&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Baby.</h3></div>
#  <h4>#A061744</h4>
#  <p></p>
#  <h6>My name is Baby</h6>
#  <h6>I am a Female, Gray Tiger, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061744"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061744&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Snap.</h3></div>
#  <h4>#A059534</h4>
#  <p></p>
#  <h6>My name is Snap</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 5 pounds.</h6>
#  <h6>My adoption price is $125.</h6>
#  <h6>I have been at the shelter since 02/12/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059534"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059534&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Sheba.</h3></div>
#  <h4>#A060145</h4>
#  <p>I am in a foster home, email adoptions@lawrencehumane.org to learn more about me.</p>
#  <h6>My name is Sheba</h6>
#  <h6>I am a Female, Brown, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 8 years old.</h6>
#  <h6>I weigh approximately 54 pounds.</h6>
#  <h6>My adoption price is $75.</h6>
#  <h6>I have been at the shelter since 11/27/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060145"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060145&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Pua.</h3></div>
#  <h4>#A059765</h4>
#  <p>I am in a foster home. Email adoptions@lawrencehumane.org to learn more about me!</p>
#  <h6>My name is Pua</h6>
#  <h6>I am a Female, White, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 1 year and 8 months old.</h6>
#  <h6>I weigh approximately 51 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 12/16/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059765"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059765&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Nova.</h3></div>
#  <h4>#A061104</h4>
#  <p></p>
#  <h6>My name is Nova</h6>
#  <h6>I am a Female, White, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years and 1 month old.</h6>
#  <h6>I weigh approximately 8 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/11/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061104"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061104&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Maverick.</h3></div>
#  <h4>#A060838</h4>
#  <p></p>
#  <h6>My name is Maverick</h6>
#  <h6>I am a Male, Gray, Alaskan Husky. </h6>
#  <h6>The shelter staff think I am about 16 weeks old.</h6>
#  <h6>I weigh approximately 25 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/09/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060838"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060838&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Tiger.</h3></div>
#  <h4>#A060849</h4>
#  <p></p>
#  <h6>My name is Tiger</h6>
#  <h6>I am a Male, Brown Brindle, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 1 year and 2 months old.</h6>
#  <h6>I weigh approximately 47 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 12/28/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060849"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060849&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Grayson.</h3></div>
#  <h4>#A061098</h4>
#  <p></p>
#  <h6>My name is Grayson</h6>
#  <h6>I am a Male, Gray, Domestic Longhair. </h6>
#  <h6>The shelter staff think I am about 6 years old.</h6>
#  <h6>I weigh approximately 12 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/11/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061098"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061098&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Gabe.</h3></div>
#  <h4>#A060779</h4>
#  <p></p>
#  <h6>My name is Gabe</h6>
#  <h6>I am a Male, Brown Tabby, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years and 2 months old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/25/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060779"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060779&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Zuri.</h3></div>
#  <h4>#A983966</h4>
#  <p></p>
#  <h6>My name is Zuri</h6>
#  <h6>I am a Female, Red, Australian Shepherd. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 50 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/05/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A983966"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A983966&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Eeyore.</h3></div>
#  <h4>#A060976</h4>
#  <p></p>
#  <h6>My name is Eeyore</h6>
#  <h6>I am a Male, Black, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 13 weeks old.</h6>
#  <h6>I weigh approximately 11 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 01/05/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060976"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060976&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Chad.</h3></div>
#  <h4>#A060543</h4>
#  <p></p>
#  <h6>My name is Chad</h6>
#  <h6>I am a Male, White, Border Collie. </h6>
#  <h6>The shelter staff think I am about 1 year and 2 months old.</h6>
#  <h6>I weigh approximately 56 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 12/08/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060543"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060543&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Molly.</h3></div>
#  <h4>#A060488</h4>
#  <p></p>
#  <h6>My name is Molly</h6>
#  <h6>I am a Female, White, Australian Cattle Dog. </h6>
#  <h6>The shelter staff think I am about 16 weeks old.</h6>
#  <h6>I weigh approximately 21 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 01/27/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060488"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060488&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Sheeva.</h3></div>
#  <h4>#A060745</h4>
#  <p></p>
#  <h6>My name is Sheeva</h6>
#  <h6>I am a Female, White, American Bulldog. </h6>
#  <h6>The shelter staff think I am about 2 years and 2 months old.</h6>
#  <h6>I weigh approximately 67 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 12/17/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060745"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060745&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Nala.</h3></div>
#  <h4>#A061733</h4>
#  <p></p>
#  <h6>My name is Nala</h6>
#  <h6>I am a Female, Brown, Alaskan Husky. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 17 pounds.</h6>
#  <h6>My adoption price is $400.</h6>
#  <h6>I have been at the shelter since 02/14/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061733"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061733&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Crumb.</h3></div>
#  <h4>#A061584</h4>
#  <p></p>
#  <h6>My name is Crumb</h6>
#  <h6>I am a Female, Brown Brindle, Mastiff. </h6>
#  <h6>The shelter staff think I am about 14 weeks old.</h6>
#  <h6>I weigh approximately 16 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061584"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061584&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Cream.</h3></div>
#  <h4>#A061591</h4>
#  <p></p>
#  <h6>My name is Cream</h6>
#  <h6>I am a Female, Black, German Shorthaired Pointer. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 20 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/08/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061591"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061591&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Nougat.</h3></div>
#  <h4>#A061765</h4>
#  <p></p>
#  <h6>My name is Nougat</h6>
#  <h6>I am a Male, White, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year old.</h6>
#  <h6>I weigh approximately 8 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061765"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061765&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Pop.</h3></div>
#  <h4>#A059533</h4>
#  <p></p>
#  <h6>My name is Pop</h6>
#  <h6>I am a Female, Calico, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 5 pounds.</h6>
#  <h6>My adoption price is $125.</h6>
#  <h6>I have been at the shelter since 02/12/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059533"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059533&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Beans.</h3></div>
#  <h4>#A061623</h4>
#  <p></p>
#  <h6>My name is Beans</h6>
#  <h6>I am a Male, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year and 6 months old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/09/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061623"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061623&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Albie.</h3></div>
#  <h4>#A061601</h4>
#  <p></p>
#  <h6>My name is Albie</h6>
#  <h6>I am a Male, Brown, Cocker Spaniel. </h6>
#  <h6>The shelter staff think I am about 6 years old.</h6>
#  <h6>I weigh approximately 25 pounds.</h6>
#  <h6>My adoption price is $250.</h6>
#  <h6>I have been at the shelter since 02/08/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061601"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061601&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Crackle.</h3></div>
#  <h4>#A059535</h4>
#  <p></p>
#  <h6>My name is Crackle</h6>
#  <h6>I am a Male, White, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $125.</h6>
#  <h6>I have been at the shelter since 02/12/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059535"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059535&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Teva.</h3></div>
#  <h4>#A061762</h4>
#  <p></p>
#  <h6>My name is Teva</h6>
#  <h6>I am a Female, Brown, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years old.</h6>
#  <h6>I weigh approximately 12 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061762"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061762&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Hecate.</h3></div>
#  <h4>#A061770</h4>
#  <p></p>
#  <h6>My name is Hecate</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year and 6 months old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061770"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061770&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Rainbow.</h3></div>
#  <h4>#A061707</h4>
#  <p></p>
#  <h6>My name is Rainbow</h6>
#  <h6>I am a Female, Calico, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/14/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061707"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061707&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Goldie.</h3></div>
#  <h4>#A061706</h4>
#  <p></p>
#  <h6>My name is Goldie</h6>
#  <h6>I am a Male, Orange Tiger, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 15 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/14/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061706"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061706&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Rune.</h3></div>
#  <h4>#A061514</h4>
#  <p>I am at the Petsmart on Iowa Street in Lawrence, KS!</p>
#  <h6>My name is Rune</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/03/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061514"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061514&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Louie.</h3></div>
#  <h4>#A061365</h4>
#  <p></p>
#  <h6>My name is Louie</h6>
#  <h6>I am a Female, Brown Brindle, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 11 months old.</h6>
#  <h6>I weigh approximately 31 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/27/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061365"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061365&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Moxie.</h3></div>
#  <h4>#A060731</h4>
#  <p></p>
#  <h6>My name is Moxie</h6>
#  <h6>I am a Female, Brown Brindle, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 1 year and 2 months old.</h6>
#  <h6>I weigh approximately 49 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/31/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060731"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060731&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Shroom.</h3></div>
#  <h4>#A061652</h4>
#  <p></p>
#  <h6>My name is Shroom</h6>
#  <h6>I am a Male, Chocolate Point, Siamese. </h6>
#  <h6>The shelter staff think I am about 6 years old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061652"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061652&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Zeppelin.</h3></div>
#  <h4>#A061657</h4>
#  <p></p>
#  <h6>My name is Zeppelin</h6>
#  <h6>I am a Male, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 6 months old.</h6>
#  <h6>I weigh approximately 6 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061657"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061657&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Sherrie.</h3></div>
#  <h4>#A061574</h4>
#  <p></p>
#  <h6>My name is Sherrie</h6>
#  <h6>I am a Female, Gray, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061574"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061574&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Gaga.</h3></div>
#  <h4>#A061495</h4>
#  <p>I am at the Petsmart on Iowa Street in Lawrence, KS!</p>
#  <h6>My name is Gaga</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year and 6 months old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/01/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061495"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061495&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Gordo.</h3></div>
#  <h4>#A061220</h4>
#  <p></p>
#  <h6>My name is Gordo</h6>
#  <h6>I am a Male, Black, Boston Terrier. </h6>
#  <h6>The shelter staff think I am about 9 months old.</h6>
#  <h6>I weigh approximately 28 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/30/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061220"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061220&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Boomer.</h3></div>
#  <h4>#A061432</h4>
#  <p>I am at the Petsmart on Iowa Street in Lawrence, KS!</p>
#  <h6>My name is Boomer</h6>
#  <h6>I am a Male, Orange, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years and 7 months old.</h6>
#  <h6>I weigh approximately 12 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/30/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061432"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061432&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Asmodeus.</h3></div>
#  <h4>#A061419</h4>
#  <p></p>
#  <h6>My name is Asmodeus</h6>
#  <h6>I am a Male, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 7 months old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/30/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061419"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061419&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Angel.</h3></div>
#  <h4>#A061340</h4>
#  <p>I'm bonded with Precious (A061339) -- adopt us both for just $90 and get twice the purrs, twice the love!</p>
#  <h6>My name is Angel</h6>
#  <h6>I am a Female, Calico, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 9 years old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/25/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061340"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061340&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Pineapple.</h3></div>
#  <h4>#A060752</h4>
#  <p>I am currently in foster care so email adoptions@lawrencehumane.org to learn more about me!</p>
#  <h6>My name is Pineapple</h6>
#  <h6>I am a Male, Brown, Beagle. </h6>
#  <h6>The shelter staff think I am about 10 months old.</h6>
#  <h6>I weigh approximately 32 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060752"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060752&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Luau.</h3></div>
#  <h4>#A061368</h4>
#  <p></p>
#  <h6>My name is Luau</h6>
#  <h6>I am a Female, Brown Brindle, Catahoula Leopard Hound. </h6>
#  <h6>The shelter staff think I am about 1 year and 1 month old.</h6>
#  <h6>I weigh approximately 47 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/27/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061368"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061368&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Smith.</h3></div>
#  <h4>#A061568</h4>
#  <p></p>
#  <h6>My name is Smith</h6>
#  <h6>I am a Male, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 11 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061568"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061568&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Kiki.</h3></div>
#  <h4>#A061660</h4>
#  <p>I am bonded to my best friend Patches (A061661), take us home for 2x the kitty love. Our combined adoption fee is $90.</p>
#  <h6>My name is Kiki</h6>
#  <h6>I am a Female, Gray, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 9 months old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061660"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061660&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Asher.</h3></div>
#  <h4>#A061656</h4>
#  <p></p>
#  <h6>My name is Asher</h6>
#  <h6>I am a Male, Black Smoke, Domestic Longhair. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061656"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061656&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Plum.</h3></div>
#  <h4>#A061502</h4>
#  <p></p>
#  <h6>My name is Plum</h6>
#  <h6>I am a Female, Tan, Australian Shepherd. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 16 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/02/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061502"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061502&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Ricky.</h3></div>
#  <h4>#A061189</h4>
#  <p></p>
#  <h6>My name is Ricky</h6>
#  <h6>I am a Male, Brown Tiger, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 01/17/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061189"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061189&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M J Wow.</h3></div>
#  <h4>#A061424</h4>
#  <p></p>
#  <h6>My name is J Wow</h6>
#  <h6>I am a Female, White, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 11 weeks old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061424"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061424&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Cactus.</h3></div>
#  <h4>#A061135</h4>
#  <p></p>
#  <h6>My name is Cactus</h6>
#  <h6>I am a Female, Fawn, Chinese Sharpei. </h6>
#  <h6>The shelter staff think I am about 2 years and 1 month old.</h6>
#  <h6>I weigh approximately 37 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/13/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061135"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061135&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Bebo.</h3></div>
#  <h4>#A061165</h4>
#  <p></p>
#  <h6>My name is Bebo</h6>
#  <h6>I am a Male, Black, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 4 years old.</h6>
#  <h6>I weigh approximately 57 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061165"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061165&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Snooki.</h3></div>
#  <h4>#A061425</h4>
#  <p></p>
#  <h6>My name is Snooki</h6>
#  <h6>I am a Female, White, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 11 weeks old.</h6>
#  <h6>I weigh approximately 4 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061425"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061425&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Lizzie.</h3></div>
#  <h4>#A061206</h4>
#  <p></p>
#  <h6>My name is Lizzie</h6>
#  <h6>I am a Female, Black, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 1 year and 1 month old.</h6>
#  <h6>I weigh approximately 32 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/17/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061206"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061206&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Squash.</h3></div>
#  <h4>#A061515</h4>
#  <p>I am at the Petco in Lawrence, KS!</p>
#  <h6>My name is Squash</h6>
#  <h6>I am a Male, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 5 pounds.</h6>
#  <h6>My adoption price is $125.</h6>
#  <h6>I have been at the shelter since 02/03/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061515"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061515&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Forest.</h3></div>
#  <h4>#A061163</h4>
#  <p></p>
#  <h6>My name is Forest</h6>
#  <h6>I am a Male, Black, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 4 years old.</h6>
#  <h6>I weigh approximately 47 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/15/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061163"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061163&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Cheyenne.</h3></div>
#  <h4>#A061468</h4>
#  <p></p>
#  <h6>My name is Cheyenne</h6>
#  <h6>I am a Female, Brown Tiger, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 1 year old.</h6>
#  <h6>I weigh approximately 8 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/01/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061468"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061468&amp;LOCATION=LAWR"/>
# ...
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Bobby.</h3></div>
#  <h4>#A059012</h4>
#  <p>Bobby is a sweet, affectionate gentleman who has thoroughly charmed the socks off of us here at Lawrence Humane. Busy or rowdy surroundings make him very cranky but if you have a low-key home, he'll happily fill it with all the purrs and biscuits you can handle! And we suspect he'll be in or near your lap every chance he gets, just so he can make sure you have all the opportunity you want for pets. What a thoughtful guy! Sounds like the cat you've been looking for? He's in a foster home so email adoptions@lawrencehumane.org to learn more and to make arrangements to meet him!</p>
#  <h6>My name is Bobby</h6>
#  <h6>I am a Male, Brown Tabby, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 11 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 09/30/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059012"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059012&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Isa.</h3></div>
#  <h4>#A059945</h4>
#  <p></p>
#  <h6>My name is Isa</h6>
#  <h6>I am a Female, Fawn, Mastiff. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 54 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 11/09/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059945"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059945&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Zane.</h3></div>
#  <h4>#A060277</h4>
#  <p></p>
#  <h6>My name is Zane</h6>
#  <h6>I am a Male, Chocolate, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 57 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 11/24/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060277"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060277&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Panda.</h3></div>
#  <h4>#A057565</h4>
#  <p></p>
#  <h6>My name is Panda</h6>
#  <h6>I am a Female, White, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 4 years old.</h6>
#  <h6>I weigh approximately 56 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 02/10/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A057565"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A057565&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Mike.</h3></div>
#  <h4>#A060377</h4>
#  <p>I'm in a foster home! Email adoptions@lawrencehumane.org to learn more about me!</p>
#  <h6>My name is Mike</h6>
#  <h6>I am a Male, White, American Bulldog. </h6>
#  <h6>The shelter staff think I am about 4 years old.</h6>
#  <h6>I weigh approximately 52 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 11/25/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060377"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060377&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Diamond.</h3></div>
#  <h4>#A059814</h4>
#  <p>I am bonded to my best friend Jewel, take us both home for twice the kitty love! Our combined adoption fee is $90. Come meet us at the Cat Cafe in downtown Lawrence, KS!</p>
#  <h6>My name is Diamond</h6>
#  <h6>I am a Female, Gray, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 10 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 11/03/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059814"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059814&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Patrick.</h3></div>
#  <h4>#A059121</h4>
#  <p></p>
#  <h6>My name is Patrick</h6>
#  <h6>I am a Male, Gray, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 8 years old.</h6>
#  <h6>I weigh approximately 56 pounds.</h6>
#  <h6>My adoption price is $75.</h6>
#  <h6>I have been at the shelter since 01/28/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059121"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059121&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Jewel.</h3></div>
#  <h4>#A059815</h4>
#  <p>I am bonded to my best friend Diamond, take us both home for twice the kitty love! Our combined adoption fee is $90. Come meet us at the Cat Cafe in downtown Lawrence, KS!</p>
#  <h6>My name is Jewel</h6>
#  <h6>I am a Female, Gray, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 9 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 11/03/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059815"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059815&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Reggie.</h3></div>
#  <h4>#A058795</h4>
#  <p>I am in a foster home! Email adoptions@lawrencehumane.org to learn more about me!</p>
#  <h6>My name is Reggie</h6>
#  <h6>I am a Male, Brown Brindle, Boxer. </h6>
#  <h6>The shelter staff think I am about 3 years old.</h6>
#  <h6>I weigh approximately 47 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 09/21/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A058795"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A058795&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Ruby.</h3></div>
#  <h4>#A058397</h4>
#  <p></p>
#  <h6>My name is Ruby</h6>
#  <h6>I am a Female, Red, Australian Cattle Dog. </h6>
#  <h6>The shelter staff think I am about 9 months old.</h6>
#  <h6>I weigh approximately 44 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/28/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A058397"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A058397&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Tubby.</h3></div>
#  <h4>#A059381</h4>
#  <p>I'm in a foster home so email my friends at adoptions@lawrencehumane.org to meet me!</p>
#  <h6>My name is Tubby</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 9 months old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 10/17/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059381"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059381&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Bones.</h3></div>
#  <h4>#A060315</h4>
#  <p></p>
#  <h6>My name is Bones</h6>
#  <h6>I am a Female, Black, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 9 years old.</h6>
#  <h6>I weigh approximately 7 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 11/25/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A060315"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A060315&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Theo.</h3></div>
#  <h4>#A058020</h4>
#  <p>I am in a foster home -- please email adoptions@lawrencehumane.org to learn more!</p>
#  <h6>My name is Theo</h6>
#  <h6>I am a Male, Black, Labrador Retriever. </h6>
#  <h6>The shelter staff think I am about 10 months old.</h6>
#  <h6>I weigh approximately 19 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 10/04/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A058020"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A058020&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Gwen.</h3></div>
#  <h4>#A059884</h4>
#  <p></p>
#  <h6>My name is Gwen</h6>
#  <h6>I am a Female, Brown, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 5 years old.</h6>
#  <h6>I weigh approximately 53 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 11/07/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059884"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059884&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Mayday.</h3></div>
#  <h4>#A059671</h4>
#  <p>I am in a foster home! Email adoptions@lawrencehumane.org to learn more about me.</p>
#  <h6>My name is Mayday</h6>
#  <h6>I am a Male, Tan, Mixed Terrier. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 32 pounds.</h6>
#  <h6>My adoption price is .</h6>
#  <h6>I have been at the shelter since 02/02/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A059671"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A059671&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Dixie.</h3></div>
#  <h4>#A058991</h4>
#  <p></p>
#  <h6>My name is Dixie</h6>
#  <h6>I am a Female, Black, German Shepherd Dog. </h6>
#  <h6>The shelter staff think I am about 5 months old.</h6>
#  <h6>I weigh approximately 25 pounds.</h6>
#  <h6>My adoption price is $300.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A058991"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A058991&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Gibson.</h3></div>
#  <h4>#A054819</h4>
#  <p></p>
#  <h6>My name is Gibson</h6>
#  <h6>I am a Male, Black, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 1 year and 5 months old.</h6>
#  <h6>I weigh approximately 55 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 09/27/2023.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A054819"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A054819&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Harley.</h3></div>
#  <h4>#A061110</h4>
#  <p></p>
#  <h6>My name is Harley</h6>
#  <h6>I am a Female, Blue, Pit Bull Terrier. </h6>
#  <h6>The shelter staff think I am about 1 year and 1 month old.</h6>
#  <h6>I weigh approximately 32 pounds.</h6>
#  <h6>My adoption price is $150.</h6>
#  <h6>I have been at the shelter since 01/11/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061110"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061110&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Ruby</h3></div>
#  <h4>#A056680</h4>
#  <p></p>
#  <h6>My name is Ruby</h6>
#  <h6>I am a Female, Black, Labrador Retriever. </h6>
#  <h6>I'm estimated to be about 2 years and 1 month old.</h6>
#  <h6>I weigh approximately 43 pounds.</h6>
#  <h6>I was found as a stray on  02/13/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A056680"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A056680&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>,
#  <div class="feed_details">
#  <div class="animalname"><h3>Hi! I'M Kickapoo.</h3></div>
#  <h4>#A061575</h4>
#  <p></p>
#  <h6>My name is Kickapoo</h6>
#  <h6>I am a Male, Brown Tiger, Domestic Shorthair. </h6>
#  <h6>The shelter staff think I am about 2 years old.</h6>
#  <h6>I weigh approximately 12 pounds.</h6>
#  <h6>My adoption price is $60.</h6>
#  <h6>I have been at the shelter since 02/07/2024.</h6>
#  <a class="animaldetails" href="https://lawrencehumane.org/details/?animal_id=A061575"></a>
#  <img src="https://petharbor.com/get_image.asp?RES=Detail&amp;ID=A061575&amp;LOCATION=LAWR"/>
#  <h6 class="dev_notice">This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.</h6>
#  </div>]

# %%
# Just poking around.
# It looks like most of the info I want on each pet in included in h6 tags.
test = messy_soup[0].find_all('h6')
for item in test:
    print(item.text)
# Out:
# My name is Trixie
# I am a Female, White, Shorthaired Rabbit.
# The shelter staff think I am about 3 years old.
# I weigh approximately 3 pounds.
# My adoption price is $40.
# I have been at the shelter since 08/09/2023.
# This information was refreshed 15 minutes ago and may not represent all of the animals at the Lawrence Humane Society.

# %%
# A plan is starting to form. Let's make a database with the following headers, then we'll fill it up.
headers = ['Picture', 'URL', 'Name', 'Sex', 'Breed', 'Age', 'Weight']

df = pd.DataFrame(columns = headers)
df
# Out:
# Empty DataFrame
# Columns: [Picture, URL, Name, Sex, Breed, Age, Weight]
# Index: []

# %%
# Now for the fun part! 
# Let's loop through the soup, clean up the elements for each pet and add it to our dataframe!
for item in messy_soup:
    picture = item.find('img')['src']
    name = item.find('h3').text.replace("Hi! I'M ", "").replace(".", "")
    url = item.find('a').get('href')
    sex = item.find_all('h6')[1].text.replace('I am a ', '').split(',')[0]
    breed = ",".join(item.find_all('h6')[1].text.replace('.', '').split(',')[1:])
    age = item.find_all('h6')[2].text.replace('.', '').split('about')[1]
    weight = item.find_all('h6')[3].text.replace('.', '').split('approximately')[1]
    individual_row_data = [picture, url, name, sex, breed, age, weight]
    length = len(df)
    df.loc[length] = individual_row_data
    
df.head()
# Out:
#                                              Picture  \
# 0  https://petharbor.com/get_image.asp?RES=Detail...
# 1  https://petharbor.com/get_image.asp?RES=Detail...
# 2  https://petharbor.com/get_image.asp?RES=Detail...
# 3  https://petharbor.com/get_image.asp?RES=Detail...
# 4  https://petharbor.com/get_image.asp?RES=Detail...
#
#                                                  URL    Name             Sex  \
# 0  https://lawrencehumane.org/details/?animal_id=...  Trixie          Female
# 1  https://lawrencehumane.org/details/?animal_id=...  Bandit            Male
# 2  https://lawrencehumane.org/details/?animal_id=...                    Male
# 3  https://lawrencehumane.org/details/?animal_id=...          Unknown Gender
# 4  https://lawrencehumane.org/details/?animal_id=...  Turkey          Female
#
#                          Breed            Age     Weight
# 0   White, Shorthaired Rabbit     3 years old   3 pounds
# 1                  White, Rat      1 year old   1 pounds
# 2     Gray, Domestic Longhair     5 years old   9 pounds
# 3   Black, Domestic Shorthair         Unknown
# 4            Yellow, Parakeet    5 months old

# %%
# Now I have a dataframe with every animal at the shelter! Neat!
# Let's filter it down to the ten dogs I had my eye on.
top_ten = ['Maximus', 'Eeyore', 'Crumb', 'Wilbur', 'Iggy', 'Dj Pauly D', 'Rosie', 'Xavier', 'Booie', 'Dixie']
top_ten_df = df[df['Name'].isin(top_ten)]
top_ten_df
# Out:
#                                                Picture  \
# 10   https://petharbor.com/get_image.asp?RES=Detail...
# 23   https://petharbor.com/get_image.asp?RES=Detail...
# 28   https://petharbor.com/get_image.asp?RES=Detail...
# 73   https://petharbor.com/get_image.asp?RES=Detail...
# 75   https://petharbor.com/get_image.asp?RES=Detail...
# 89   https://petharbor.com/get_image.asp?RES=Detail...
# 102  https://petharbor.com/get_image.asp?RES=Detail...
# 103  https://petharbor.com/get_image.asp?RES=Detail...
# 122  https://petharbor.com/get_image.asp?RES=Detail...
#
#                                                    URL        Name     Sex  \
# 10   https://lawrencehumane.org/details/?animal_id=...     Maximus    Male
# 23   https://lawrencehumane.org/details/?animal_id=...      Eeyore    Male
# 28   https://lawrencehumane.org/details/?animal_id=...       Crumb  Female
# 73   https://lawrencehumane.org/details/?animal_id=...  Dj Pauly D    Male
# 75   https://lawrencehumane.org/details/?animal_id=...        Iggy    Male
# 89   https://lawrencehumane.org/details/?animal_id=...       Rosie  Female
# 102  https://lawrencehumane.org/details/?animal_id=...       Booie    Male
# 103  https://lawrencehumane.org/details/?animal_id=...      Xavier    Male
# 122  https://lawrencehumane.org/details/?animal_id=...       Dixie  Female
#
#                             Breed                        Age      Weight
# 10         Brown, Mixed Shepherd               11 months old   38 pounds
# 23       Black, Pit Bull Terrier                13 weeks old   11 pounds
# 28        Brown Brindle, Mastiff                14 weeks old   16 pounds
# 73       White, Pit Bull Terrier                11 weeks old    7 pounds
# 75         Red, Pit Bull Terrier                7 months old   42 pounds
# 89          Black, Alaskan Husky    2 years and 3 months old   59 pounds
# 102   Yellow, Labrador Retriever    2 years and 5 months old   57 pounds
# 103             White, Dalmatian                 3 years old   48 pounds
# 122   Black, German Shepherd Dog                5 months old   25 pounds

# %%
# This is exactly what I wanted! 
# Now to save this as a csv to send to my husband, who will laugh at me for turning this into a data project.
top_ten_df.to_csv('top_ten.csv')
